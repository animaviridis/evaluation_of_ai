# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import aux_functions as aux
import plotting_functions as plots

import matplotlib
# %matplotlib inline

# %%
main_data, keys = aux.prepare_data()

# %%
fig = plots.make_plot(main_data, keys['general'], kind='pie', fig_kwargs=dict(figsize=(9,6)))
fig.subplots_adjust(left=0.0, hspace=0.25)

# %%
fig = plots.make_plot(main_data, keys['search_engines'][0:2], kind=['pie', 'bar'], fig_kwargs=dict(figsize=(8,6)), nrows=1)
fig.subplots_adjust(left=0.0, wspace=0.5)

# %%
fig = plots.make_plot(main_data, keys['yippy'], kind='bar', fig_kwargs=dict(figsize=(9,6)), break_labels=False)
fig.subplots_adjust(left=0.0, hspace=0.3, wspace=0.2)

# %%
fig = plots.make_plot(main_data, keys['tasks'], kind='bar', fig_kwargs=dict(figsize=(12,12)), nrows=len(keys['tasks'])//2)
fig.subplots_adjust(left=0.0, hspace=0.4, wspace=0.1)
