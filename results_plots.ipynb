# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import aux_functions as aux
import plotting_functions as plots

import matplotlib
# %matplotlib inline

# %%
main_data, keys = aux.prepare_data()

# %%
main_data.head()
# Out:
#     Sygnatura czasowa  Consent Are you a native English speaker?  \
# 0 2019-11-22 17:05:30  Confirm                                No
# 1 2019-11-25 13:17:13  Confirm                               Yes
# 2 2019-11-25 13:25:04  Confirm                                No
# 3 2019-11-25 13:25:14  Confirm                                No
# 4 2019-11-25 13:30:00  Confirm                               Yes
#
#   What age group do you belong to? What is your gender?  \
# 0                            18-22               Female
# 1                            18-22               Female
# 2                            18-22                 Male
# 3                            18-22                 Male
# 4                            18-22                 Male
#
#           What field do you study in?  \
# 0                     Business School
# 1            Arts and Social Sciences
# 2  Chemistry, Physics and Mathematics
# 3  Chemistry, Physics and Mathematics
# 4                         Engineering
#
#   Which search engine do you normally use?  \
# 0                                   Google
# 1                                   Google
# 2                                   Google
# 3                                   Google
# 4                                   Google
#
#   Which search engines have you used before?  \
# 0                          Google;Baidu;Bing
# 1                          Google;Yahoo;Bing
# 2                  Google;Yahoo;Bing;AOL;Ask
# 3                   Google;DuckDuckGo;Ecosia
# 4                          Google;Yahoo;Bing
#
#   Have you used Yippy before participating in the survey?  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#             What was your chosen phrase?  ...  \
# 0                                  K-pop  ...
# 1                             Psychology  ...
# 2                      imaginary numbers  ...
# 3  toronto raptors trading kawhi leonard  ...
# 4                       basketball teams  ...
#
#    Yippy clustering feature - how useful did you find it?  \
# 0                                                  9
# 1                                                  9
# 2                                                  8
# 3                                                  6
# 4                                                 10
#
#    How easy did you find Yippy to use?  \
# 0                                   10
# 1                                   10
# 2                                    7
# 3                                   10
# 4                                    9
#
#    How would you rate the speed of the search?  \
# 0                                           10
# 1                                            8
# 2                                           10
# 3                                            6
# 4                                           10
#
#    How much do you prefer Google over Yippy?  \
# 0                                          7
# 1                                          5
# 2                                          5
# 3                                          1
# 4                                          5
#
#                       What did you like about Yippy?  \
# 0                                                NaN
# 1                         The suggestion of clusters
# 2  cluster allows to find similar topics related ...
# 3  News seemed to be more relevant, whereas googl...
# 4  like how clustering feature helps narrow down ...
#
#                   What did you not like about Yippy?  \
# 0                                                NaN
# 1  There were very little results for videos (onl...
# 2                    Design looks slightly out dated
# 3             Nothing appeared to me as 'unlikeable'
# 4                           design could look better
#
#    How likely are you to return to Yippy?  Any other comments and remarks?  \
# 0                                      10                              yes
# 1                                       3                              NaN
# 2                                       4                              NaN
# 3                                       5                              NaN
# 4                                       7                              NaN
#
#    What did you think of our evaluation?  \
# 0                                      7
# 1                                     10
# 2                                      8
# 3                                     10
# 4                                     10
#
#    Comment and Remarks on the evaluation?
# 0                       Baby yoda? really
# 1                            BABY YODA <3
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
# [5 rows x 29 columns]

# %%
# divide questions
k = list(main_data.keys())
keys = dict()
keys['general'] = k[2:6]
keys['search_engines'] = k[6:9]
keys['phrase'] = k[9:10]
keys['tasks'] = k[10:18]
keys['clustering'] = k[18:20]
keys['yippy'] = k[20:23] + k[25:26]
keys['remarks_yippy'] = k[23:24]
keys['remarks_eval'] = [k[26], k[28]]
keys['eval'] = [k[27]]

# %%
fig = plots.make_plot(main_data, keys['general'], type='pie', fig_kwargs=dict(figsize=(9,6)), show=False)
fig.subplots_adjust(left=0.0, hspace=0.25)

# %%
fig = plots.make_plot(main_data, keys['yippy'], type='bar', fig_kwargs=dict(figsize=(9,6)), break_labels=False, show=False)
fig.subplots_adjust(left=0.0, hspace=0.3, wspace=0.2)

# %%
fig = plots.make_plot(main_data, keys['tasks'], type='bar', fig_kwargs=dict(figsize=(12,12)), show=False,
                      nrows=len(keys['tasks'])//2)
fig.subplots_adjust(left=0.0, hspace=0.4, wspace=0.1)
