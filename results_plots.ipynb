# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import aux_functions as aux

import matplotlib
# %matplotlib inline

# %%
main_data = pd.read_csv('data/main_survey.csv')

# %%
main_data.head()
# Out:
#            Sygnatura czasowa  \
# 0  2019/11/22 5:05:30 PM GMT
# 1  2019/11/25 1:17:13 PM GMT
# 2  2019/11/25 1:25:04 PM GMT
# 3  2019/11/25 1:25:14 PM GMT
# 4  2019/11/25 1:30:00 PM GMT
#
#   I confirm that I have read and understood the above statements (check the box), If you are doing the survey in person, check the box when you have signed the consent form.  \
# 0                                            Confirm
# 1                                            Confirm
# 2                                            Confirm
# 3                                            Confirm
# 4                                            Confirm
#
#   Are you a native English speaker? What age group do you belong to? Gender?  \
# 0                                No                            18-22  Female
# 1                               Yes                            18-22  Female
# 2                                No                            18-22    Male
# 3                                No                            18-22    Male
# 4                               Yes                            18-22    Male
#
#           What Field do you study in?  \
# 0                     Business School
# 1            Arts and Social Sciences
# 2  Chemistry, Physics and Mathematics
# 3  Chemistry, Physics and Mathematics
# 4                         Engineering
#
#   Which Search engine do you normally use? (Pick One)  \
# 0                                             Google
# 1                                             Google
# 2                                             Google
# 3                                             Google
# 4                                             Google
#
#   Which search engines have you used before? (tick all options that apply to you)  \
# 0                                  Google;Baidu;Bing
# 1                                  Google;Yahoo;Bing
# 2                          Google;Yahoo;Bing;AOL;Ask
# 3                           Google;DuckDuckGo;Ecosia
# 4                                  Google;Yahoo;Bing
#
#   Have you used Yippy before participating in the survey?  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#             What was your chosen phrase?  ...  \
# 0                                  K-pop  ...
# 1                             Psychology  ...
# 2                      imaginary numbers  ...
# 3  toronto raptors trading kawhi leonard  ...
# 4                       basketball teams  ...
#
#    Did you find the feature useful?  How easy did you find Yippy to use?  \
# 0                                 9                                   10
# 1                                 9                                   10
# 2                                 8                                    7
# 3                                 6                                   10
# 4                                10                                    9
#
#    How would you rate the speed of the search ?  \
# 0                                            10
# 1                                             8
# 2                                            10
# 3                                             6
# 4                                            10
#
#    How much do you prefer Google over Yippy  \
# 0                                         7
# 1                                         5
# 2                                         5
# 3                                         1
# 4                                         5
#
#                       What did you like about Yippy?  \
# 0                                                NaN
# 1                         The suggestion of clusters
# 2  cluster allows to find similar topics related ...
# 3  News seemed to be more relevant, whereas googl...
# 4  like how clustering feature helps narrow down ...
#
#                   What did you not like about Yippy?  \
# 0                                                NaN
# 1  There were very little results for videos (onl...
# 2                    Design looks slightly out dated
# 3             Nothing appeared to me as 'unlikeable'
# 4                           design could look better
#
#    How likely are you to return to Yippy?  Any other comments and remarks?  \
# 0                                      10                              yes
# 1                                       3                              NaN
# 2                                       4                              NaN
# 3                                       5                              NaN
# 4                                       7                              NaN
#
#    What did you think of our evaluation?  \
# 0                                      7
# 1                                     10
# 2                                      8
# 3                                     10
# 4                                     10
#
#    Comment and Remarks on the evaluation?
# 0                       Baby yoda? really
# 1                            BABY YODA <3
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
# [5 rows x 29 columns]

# %%
# divide questions
k = list(main_data.keys())
keys = dict()
keys['general'] = k[2:6]
keys['search_engines'] = k[6:9]
keys['phrase'] = k[9:10]
keys['tasks'] = k[10:18]
keys['clustering'] = k[18:20]
keys['yippy'] = k[20:23] + k[25:26]
keys['remarks_yippy'] = k[23:24]
keys['remarks_eval'] = [k[26], k[28]]
keys['eval'] = [k[27]]

# %%
fig = aux.pie_subplots(main_data, keys['general'], fig_kwargs=dict(figsize=(10,6)),
                       title="Socio-demographic profile of the main study population", show=False)
fig.subplots_adjust(top=0.75)
